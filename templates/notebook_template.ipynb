# %% [markdown]
# # Migrated from Dataiku
# **Original recipe:** `{{recipe_name}}`
# **Source project:** `{{project_key}}`
# **Migration date:** `{{migration_date}}`
# **Review flags:** {{review_flags}}

# %%
# Configuration & Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
# Input: Load datasets
{{input_cells}}

# %%
# Migrated logic
{{migrated_code}}

# %%
# Output: Write results
{{output_cells}}
